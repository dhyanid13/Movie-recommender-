# %%
# %matplotlib inline  
 
import pandas as pd


ratings = pd.read_csv(r'C:\Users\Lenovo\Desktop\ratings.csv')

movies = pd.read_csv(r'C:\Users\Lenovo\Desktop\movies.csv')

ratings = pd.merge(movies, ratings)

ratings.head()
# Out:
#    movieId             title  userId  rating
# 0        1  Toy Story (1995)       1     4.0
# 1        1  Toy Story (1995)       5     4.0
# 2        1  Toy Story (1995)       7     4.5
# 3        1  Toy Story (1995)      15     2.5
# 4        1  Toy Story (1995)      17     4.5

# %%
userRatings = ratings.pivot_table(index=['userId'],columns=['title'],values='rating')
userRatings.head()
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# 5                          NaN                  NaN
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
#
# title   'burbs, The (1989)  'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# 1                      NaN                   NaN                          NaN
# 2                      NaN                   NaN                          NaN
# 3                      NaN                   NaN                          NaN
# 4                      NaN                   NaN                          NaN
# 5                      NaN                   NaN                          NaN
#
# title   *batteries not included (1987)  ...  Zulu (2013)  [REC] (2007)  \
# userId                                  ...
# 1                                  NaN  ...          NaN           NaN
# 2                                  NaN  ...          NaN           NaN
# 3                                  NaN  ...          NaN           NaN
# 4                                  NaN  ...          NaN           NaN
# 5                                  NaN  ...          NaN           NaN
#
# title   [REC]² (2009)  [REC]³ 3 Génesis (2012)  \
# userId
# 1                 NaN                      NaN
# 2                 NaN                      NaN
# 3                 NaN                      NaN
# 4                 NaN                      NaN
# 5                 NaN                      NaN
#
# title   anohana: The Flower We Saw That Day - The Movie (2013)  \
# userId
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
#
# title   eXistenZ (1999)  xXx (2002)  xXx: State of the Union (2005)  \
# userId
# 1                   NaN         NaN                             NaN
# 2                   NaN         NaN                             NaN
# 3                   NaN         NaN                             NaN
# 4                   NaN         NaN                             NaN
# 5                   NaN         NaN                             NaN
#
# title   ¡Three Amigos! (1986)  À nous la liberté (Freedom for Us) (1931)
# userId
# 1                         4.0                                        NaN
# 2                         NaN                                        NaN
# 3                         NaN                                        NaN
# 4                         NaN                                        NaN
# 5                         NaN                                        NaN
#
# [5 rows x 9719 columns]

# %%
corrMatrix = userRatings.corr()
corrMatrix.head()
# Out:
# title                                    '71 (2014)  \
# title
# '71 (2014)                                      NaN
# 'Hellboy': The Seeds of Creation (2004)         NaN
# 'Round Midnight (1986)                          NaN
# 'Salem's Lot (2004)                             NaN
# 'Til There Was You (1997)                       NaN
#
# title                                    'Hellboy': The Seeds of Creation (2004)  \
# title
# '71 (2014)                                                                   NaN
# 'Hellboy': The Seeds of Creation (2004)                                      NaN
# 'Round Midnight (1986)                                                       NaN
# 'Salem's Lot (2004)                                                          NaN
# 'Til There Was You (1997)                                                    NaN
#
# title                                    'Round Midnight (1986)  \
# title
# '71 (2014)                                                  NaN
# 'Hellboy': The Seeds of Creation (2004)                     NaN
# 'Round Midnight (1986)                                      NaN
# 'Salem's Lot (2004)                                         NaN
# 'Til There Was You (1997)                                   NaN
#
# title                                    'Salem's Lot (2004)  \
# title
# '71 (2014)                                               NaN
# 'Hellboy': The Seeds of Creation (2004)                  NaN
# 'Round Midnight (1986)                                   NaN
# 'Salem's Lot (2004)                                      NaN
# 'Til There Was You (1997)                                NaN
#
# title                                    'Til There Was You (1997)  \
# title
# '71 (2014)                                                     NaN
# 'Hellboy': The Seeds of Creation (2004)                        NaN
# 'Round Midnight (1986)                                         NaN
# 'Salem's Lot (2004)                                            NaN
# 'Til There Was You (1997)                                      1.0
#
# title                                    'Tis the Season for Love (2015)  \
# title
# '71 (2014)                                                           NaN
# 'Hellboy': The Seeds of Creation (2004)                              NaN
# 'Round Midnight (1986)                                               NaN
# 'Salem's Lot (2004)                                                  NaN
# 'Til There Was You (1997)                                            NaN
#
# title                                    'burbs, The (1989)  \
# title
# '71 (2014)                                              NaN
# 'Hellboy': The Seeds of Creation (2004)                 NaN
# 'Round Midnight (1986)                                  NaN
# 'Salem's Lot (2004)                                     NaN
# 'Til There Was You (1997)                               NaN
#
# title                                    'night Mother (1986)  \
# title
# '71 (2014)                                                NaN
# 'Hellboy': The Seeds of Creation (2004)                   NaN
# 'Round Midnight (1986)                                    NaN
# 'Salem's Lot (2004)                                       NaN
# 'Til There Was You (1997)                                 NaN
#
# title                                    (500) Days of Summer (2009)  \
# title
# '71 (2014)                                                       NaN
# 'Hellboy': The Seeds of Creation (2004)                          NaN
# 'Round Midnight (1986)                                           NaN
# 'Salem's Lot (2004)                                              NaN
# 'Til There Was You (1997)                                        NaN
#
# title                                    *batteries not included (1987)  ...  \
# title                                                                    ...
# '71 (2014)                                                          NaN  ...
# 'Hellboy': The Seeds of Creation (2004)                             NaN  ...
# 'Round Midnight (1986)                                              NaN  ...
# 'Salem's Lot (2004)                                                 NaN  ...
# 'Til There Was You (1997)                                           NaN  ...
#
# title                                    Zulu (2013)  [REC] (2007)  \
# title
# '71 (2014)                                       NaN           NaN
# 'Hellboy': The Seeds of Creation (2004)          NaN           NaN
# 'Round Midnight (1986)                           NaN           NaN
# 'Salem's Lot (2004)                              NaN           NaN
# 'Til There Was You (1997)                        NaN           NaN
#
# title                                    [REC]² (2009)  \
# title
# '71 (2014)                                         NaN
# 'Hellboy': The Seeds of Creation (2004)            NaN
# 'Round Midnight (1986)                             NaN
# 'Salem's Lot (2004)                                NaN
# 'Til There Was You (1997)                          NaN
#
# title                                    [REC]³ 3 Génesis (2012)  \
# title
# '71 (2014)                                                   NaN
# 'Hellboy': The Seeds of Creation (2004)                      NaN
# 'Round Midnight (1986)                                       NaN
# 'Salem's Lot (2004)                                          NaN
# 'Til There Was You (1997)                                    NaN
#
# title                                    anohana: The Flower We Saw That Day - The Movie (2013)  \
# title
# '71 (2014)                                                                             NaN
# 'Hellboy': The Seeds of Creation (2004)                                                NaN
# 'Round Midnight (1986)                                                                 NaN
# 'Salem's Lot (2004)                                                                    NaN
# 'Til There Was You (1997)                                                              NaN
#
# title                                    eXistenZ (1999)  xXx (2002)  \
# title
# '71 (2014)                                           NaN         NaN
# 'Hellboy': The Seeds of Creation (2004)              NaN         NaN
# 'Round Midnight (1986)                               NaN         NaN
# 'Salem's Lot (2004)                                  NaN         NaN
# 'Til There Was You (1997)                            NaN         NaN
#
# title                                    xXx: State of the Union (2005)  \
# title
# '71 (2014)                                                          NaN
# 'Hellboy': The Seeds of Creation (2004)                             NaN
# 'Round Midnight (1986)                                              NaN
# 'Salem's Lot (2004)                                                 NaN
# 'Til There Was You (1997)                                           NaN
#
# title                                    ¡Three Amigos! (1986)  \
# title
# '71 (2014)                                                 NaN
# 'Hellboy': The Seeds of Creation (2004)                    NaN
# 'Round Midnight (1986)                                     NaN
# 'Salem's Lot (2004)                                        NaN
# 'Til There Was You (1997)                                  NaN
#
# title                                    À nous la liberté (Freedom for Us) (1931)
# title
# '71 (2014)                                                                     NaN
# 'Hellboy': The Seeds of Creation (2004)                                        NaN
# 'Round Midnight (1986)                                                         NaN
# 'Salem's Lot (2004)                                                            NaN
# 'Til There Was You (1997)                                                      NaN
#
# [5 rows x 9719 columns]

# %%
corrMatrix = userRatings.corr(method='pearson', min_periods=100)
corrMatrix.head()
# Out:
# title                                    '71 (2014)  \
# title
# '71 (2014)                                      NaN
# 'Hellboy': The Seeds of Creation (2004)         NaN
# 'Round Midnight (1986)                          NaN
# 'Salem's Lot (2004)                             NaN
# 'Til There Was You (1997)                       NaN
#
# title                                    'Hellboy': The Seeds of Creation (2004)  \
# title
# '71 (2014)                                                                   NaN
# 'Hellboy': The Seeds of Creation (2004)                                      NaN
# 'Round Midnight (1986)                                                       NaN
# 'Salem's Lot (2004)                                                          NaN
# 'Til There Was You (1997)                                                    NaN
#
# title                                    'Round Midnight (1986)  \
# title
# '71 (2014)                                                  NaN
# 'Hellboy': The Seeds of Creation (2004)                     NaN
# 'Round Midnight (1986)                                      NaN
# 'Salem's Lot (2004)                                         NaN
# 'Til There Was You (1997)                                   NaN
#
# title                                    'Salem's Lot (2004)  \
# title
# '71 (2014)                                               NaN
# 'Hellboy': The Seeds of Creation (2004)                  NaN
# 'Round Midnight (1986)                                   NaN
# 'Salem's Lot (2004)                                      NaN
# 'Til There Was You (1997)                                NaN
#
# title                                    'Til There Was You (1997)  \
# title
# '71 (2014)                                                     NaN
# 'Hellboy': The Seeds of Creation (2004)                        NaN
# 'Round Midnight (1986)                                         NaN
# 'Salem's Lot (2004)                                            NaN
# 'Til There Was You (1997)                                      NaN
#
# title                                    'Tis the Season for Love (2015)  \
# title
# '71 (2014)                                                           NaN
# 'Hellboy': The Seeds of Creation (2004)                              NaN
# 'Round Midnight (1986)                                               NaN
# 'Salem's Lot (2004)                                                  NaN
# 'Til There Was You (1997)                                            NaN
#
# title                                    'burbs, The (1989)  \
# title
# '71 (2014)                                              NaN
# 'Hellboy': The Seeds of Creation (2004)                 NaN
# 'Round Midnight (1986)                                  NaN
# 'Salem's Lot (2004)                                     NaN
# 'Til There Was You (1997)                               NaN
#
# title                                    'night Mother (1986)  \
# title
# '71 (2014)                                                NaN
# 'Hellboy': The Seeds of Creation (2004)                   NaN
# 'Round Midnight (1986)                                    NaN
# 'Salem's Lot (2004)                                       NaN
# 'Til There Was You (1997)                                 NaN
#
# title                                    (500) Days of Summer (2009)  \
# title
# '71 (2014)                                                       NaN
# 'Hellboy': The Seeds of Creation (2004)                          NaN
# 'Round Midnight (1986)                                           NaN
# 'Salem's Lot (2004)                                              NaN
# 'Til There Was You (1997)                                        NaN
#
# title                                    *batteries not included (1987)  ...  \
# title                                                                    ...
# '71 (2014)                                                          NaN  ...
# 'Hellboy': The Seeds of Creation (2004)                             NaN  ...
# 'Round Midnight (1986)                                              NaN  ...
# 'Salem's Lot (2004)                                                 NaN  ...
# 'Til There Was You (1997)                                           NaN  ...
#
# title                                    Zulu (2013)  [REC] (2007)  \
# title
# '71 (2014)                                       NaN           NaN
# 'Hellboy': The Seeds of Creation (2004)          NaN           NaN
# 'Round Midnight (1986)                           NaN           NaN
# 'Salem's Lot (2004)                              NaN           NaN
# 'Til There Was You (1997)                        NaN           NaN
#
# title                                    [REC]² (2009)  \
# title
# '71 (2014)                                         NaN
# 'Hellboy': The Seeds of Creation (2004)            NaN
# 'Round Midnight (1986)                             NaN
# 'Salem's Lot (2004)                                NaN
# 'Til There Was You (1997)                          NaN
#
# title                                    [REC]³ 3 Génesis (2012)  \
# title
# '71 (2014)                                                   NaN
# 'Hellboy': The Seeds of Creation (2004)                      NaN
# 'Round Midnight (1986)                                       NaN
# 'Salem's Lot (2004)                                          NaN
# 'Til There Was You (1997)                                    NaN
#
# title                                    anohana: The Flower We Saw That Day - The Movie (2013)  \
# title
# '71 (2014)                                                                             NaN
# 'Hellboy': The Seeds of Creation (2004)                                                NaN
# 'Round Midnight (1986)                                                                 NaN
# 'Salem's Lot (2004)                                                                    NaN
# 'Til There Was You (1997)                                                              NaN
#
# title                                    eXistenZ (1999)  xXx (2002)  \
# title
# '71 (2014)                                           NaN         NaN
# 'Hellboy': The Seeds of Creation (2004)              NaN         NaN
# 'Round Midnight (1986)                               NaN         NaN
# 'Salem's Lot (2004)                                  NaN         NaN
# 'Til There Was You (1997)                            NaN         NaN
#
# title                                    xXx: State of the Union (2005)  \
# title
# '71 (2014)                                                          NaN
# 'Hellboy': The Seeds of Creation (2004)                             NaN
# 'Round Midnight (1986)                                              NaN
# 'Salem's Lot (2004)                                                 NaN
# 'Til There Was You (1997)                                           NaN
#
# title                                    ¡Three Amigos! (1986)  \
# title
# '71 (2014)                                                 NaN
# 'Hellboy': The Seeds of Creation (2004)                    NaN
# 'Round Midnight (1986)                                     NaN
# 'Salem's Lot (2004)                                        NaN
# 'Til There Was You (1997)                                  NaN
#
# title                                    À nous la liberté (Freedom for Us) (1931)
# title
# '71 (2014)                                                                     NaN
# 'Hellboy': The Seeds of Creation (2004)                                        NaN
# 'Round Midnight (1986)                                                         NaN
# 'Salem's Lot (2004)                                                            NaN
# 'Til There Was You (1997)                                                      NaN
#
# [5 rows x 9719 columns]

# %%
myRatings = userRatings.loc[20].dropna()
myRatings
# Out:
# title
# 101 Dalmatians (1996)                                     3.0
# 101 Dalmatians (One Hundred and One Dalmatians) (1961)    4.0
# 6th Day, The (2000)                                       2.5
# A.I. Artificial Intelligence (2001)                       3.0
# Adanggaman (2000)                                         2.0
#                                                          ...
# X-Men (2000)                                              3.5
# X2: X-Men United (2003)                                   4.0
# Yellow Submarine (1968)                                   4.0
# Zoolander (2001)                                          3.5
# xXx (2002)                                                0.5
# Name: 20, Length: 242, dtype: float64

# %%
simCandidates = pd.Series()

for i in range(0, len(myRatings.index)):
    print ("Adding sims for " + myRatings.index[i] + "...")
    # Retrieve similar movies to this one that I rated
    sims = corrMatrix[myRatings.index[i]].dropna()
    # Now scale its similarity by how well I rated this movie
    sims = sims.map(lambda x: x * myRatings[i])
    # Add the score to the list of similarity candidates
    simCandidates = simCandidates.append(sims)
    
    
    
#Glance at our results so far:
print ("sorting...")
simCandidates.sort_values(inplace = True, ascending = False)
print (simCandidates.head(10))
# Out:
# E:\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.
# Adding sims for 101 Dalmatians (1996)...
# Adding sims for 101 Dalmatians (One Hundred and One Dalmatians) (1961)...
# Adding sims for 6th Day, The (2000)...
# Adding sims for A.I. Artificial Intelligence (2001)...
# Adding sims for Adanggaman (2000)...
# Adding sims for Aladdin (1992)...
# Adding sims for Alice in Wonderland (1951)...
# Adding sims for Almost Famous (2000)...
# Adding sims for American Pie 2 (2001)...
# Adding sims for American Psycho (2000)...
# Adding sims for American Tail, An (1986)...
# Adding sims for Anastasia (1997)...
# Adding sims for Angels in the Outfield (1994)...
# Adding sims for Annie (1982)...
# Adding sims for Antz (1998)...
# Adding sims for Atlantis: The Lost Empire (2001)...
# Adding sims for Austin Powers in Goldmember (2002)...
# Adding sims for Babe (1995)...
# Adding sims for Balto (1995)...
# Adding sims for Bambi (1942)...
# Adding sims for Beautiful Mind, A (2001)...
# Adding sims for Beauty and the Beast (1991)...
# Adding sims for Bedknobs and Broomsticks (1971)...
# Adding sims for Billy Elliot (2000)...
# Adding sims for Birds, The (1963)...
# Adding sims for Black Cauldron, The (1985)...
# Adding sims for Black Stallion, The (1979)...
# Adding sims for Blade (1998)...
# Adding sims for Blade II (2002)...
# Adding sims for Borrowers, The (1997)...
# Adding sims for Bourne Identity, The (2002)...
# Adding sims for Bowfinger (1999)...
# Adding sims for Brave Little Toaster, The (1987)...
# Adding sims for Bridget Jones's Diary (2001)...
# Adding sims for Bring It On (2000)...
# Adding sims for Bug's Life, A (1998)...
# Adding sims for Casper (1995)...
# Adding sims for Cast Away (2000)...
# Adding sims for Catch Me If You Can (2002)...
# Adding sims for Cats Don't Dance (1997)...
# Adding sims for Changing Lanes (2002)...
# Adding sims for Charlie's Angels (2000)...
# Adding sims for Charlotte's Web (1973)...
# Adding sims for Chicago (2002)...
# Adding sims for Chicken Run (2000)...
# Adding sims for Chocolat (2000)...
# Adding sims for Chorus Line, A (1985)...
# Adding sims for Christmas Story, A (1983)...
# Adding sims for Cinderella (1950)...
# Adding sims for Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000
# Adding sims for Sleeping Beauty (1959)...
# Adding sims for Snow White and the Seven Dwarfs (1937)...
# Adding sims for Soft Fruit (1999)...
# Adding sims for Sound of Music, The (1965)...
# Adding sims for South Pacific (1958)...
# Adding sims for South Park: Bigger, Longer and Uncut (1999)...
# Adding sims for Spider-Man (2002)...
# Adding sims for Spirited Away (Sen to Chihiro no kamikakushi) (2001)...
# Adding sims for Splash (1984)...
# Adding sims for Spy Game (2001)...
# Adding sims for Spy Kids (2001)...
# Adding sims for Spy Kids 2: The Island of Lost Dreams (2002)...
# Adding sims for Star Wars: Episode II - Attack of the Clones (2002)...
# Adding sims for State and Main (2000)...
# Adding sims for Stuart Little (1999)...
# Adding sims for Super Troopers (2001)...
# Adding sims for Sword in the Stone, The (1963)...
# Adding sims for Swordfish (2001)...
# Adding sims for Tao of Steve, The (2000)...
# Adding sims for Tarzan (1999)...
# Adding sims for Teenage Mutant Ninja Turtles (1990)...
# Adding sims for That Darn Cat! (1965)...
# Adding sims for The Scorpion King (2002)...
# Adding sims for Time Machine, The (2002)...
# Adding sims for Tom and Huck (1995)...
# Adding sims for Tomorrow Never Dies (1997)...
# Adding sims for Toy Story 2 (1999)...
# Adding sims for Trail of the Pink Panther (1982)...
# Adding sims for Training Day (2001)...
# Adding sims for U-571 (2000)...
# Adding sims for Unbreakable (2000)...
# Adding sims for Unfaithful (2002)...
# Adding sims for Vertical Limit (2000)...
# Adding sims for Wallace & Gromit: The Best of Aardman Animation (1996)...
# Adding sims for Wallace & Gromit: The Wrong Trousers (1993)...
# Adding sims for West Side Story (1961)...
# Adding sims for Where the Heart Is (2000)...
# Adding sims for Who Framed Roger Rabbit? (1988)...
# Adding sims for Whole Nine Yards, The (2000)...
# Adding sims for Wild Wild West (1999)...
# Adding sims for Willy Wonka & the Chocolate Factory (1971)...
# Adding sims for Wizard of Oz, The (1939)...
# Adding sims for X-Men (2000)...
# Adding sims for X2: X-Men United (2003)...
# Adding sims for Yellow Submarine (1968)...
# Adding sims for Zoolander (2001)...
# Adding sims for xXx (2002)...
# sorting...
# Lord of the Rings: The Fellowship of the Ring, The (2001)    5.0
# Beauty and the Beast (1991)                                  5.0
# Lord of the Rings: The Two Towers, The (2002)                5.0
# Lion King, The (1994)                                        5.0
# Shrek (2001)                                                 5.0
# E.T. the Extra-Terrestrial (1982)                            5.0
# Beautiful Mind, A (2001)                                     5.0
# Aladdin (1992)                                               5.0
# Willy Wonka & the Chocolate Factory (1971)                   5.0
# Gladiator (2000)                                             4.5
# dtype: float64

# %%
simCandidates = simCandidates.groupby(simCandidates.index).sum()

# %%
simCandidates.sort_values(inplace = True, ascending = False)

simCandidates.head(10)
# Out:
# Lord of the Rings: The Fellowship of the Ring, The (2001)    13.403896
# Lord of the Rings: The Two Towers, The (2002)                12.063441
# Matrix, The (1999)                                           11.662760
# Lord of the Rings: The Return of the King, The (2003)        11.640730
# Aladdin (1992)                                               10.869233
# Forrest Gump (1994)                                          10.508215
# Lion King, The (1994)                                         9.943164
# Beauty and the Beast (1991)                                   9.895794
# Shrek (2001)                                                  9.113873
# Monsters, Inc. (2001)                                         7.496631
# dtype: float64
